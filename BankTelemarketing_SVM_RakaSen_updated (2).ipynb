# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_auc_score
from sklearn.svm import SVC
from sklearn import svm
from sklearn.linear_model import SGDClassifier
from sklearn.calibration import CalibratedClassifierCV
from sklearn.model_selection import GridSearchCV

import warnings
warnings.filterwarnings("ignore")

# %%
#Loading the dataset
data=pd.read_csv('C:\\Users\\RAKA SEN\\Desktop\\Classification project\\bank-additional-full.csv',sep=";")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  object
#  15  emp.var.rate    41188 non-null  float64
#  16  cons.price.idx  41188 non-null  float64
#  17  cons.conf.idx   41188 non-null  float64
#  18  euribor3m       41188 non-null  float64
#  19  nr.employed     41188 non-null  float64
#  20  y               41188 non-null  object
# dtypes: float64(5), int64(5), object(11)
# memory usage: 6.6+ MB

# %% [markdown]
# ## Dealing with Duplicate Data

# %%
data_dup = data[data.duplicated(keep="last")]
data_dup
# Out:
#        age          job   marital            education  default housing loan  \
# 1265    39  blue-collar   married             basic.6y       no      no   no
# 12260   36      retired   married              unknown       no      no   no
# 14155   27   technician    single  professional.course       no      no   no
# 16819   47   technician  divorced          high.school       no     yes   no
# 18464   32   technician    single  professional.course       no     yes   no
# 20072   55     services   married          high.school  unknown      no   no
# 20531   41   technician   married  professional.course       no     yes   no
# 25183   39       admin.   married    university.degree       no      no   no
# 28476   24     services    single          high.school       no     yes   no
# 32505   35       admin.   married    university.degree       no     yes   no
# 36950   45       admin.   married    university.degree       no      no   no
# 38255   71      retired    single    university.degree       no      no   no
#
#          contact month day_of_week  ...  campaign  pdays  previous  \
# 1265   telephone   may         thu  ...         1    999         0
# 12260  telephone   jul         thu  ...         1    999         0
# 14155   cellular   jul         mon  ...         2    999         0
# 16819   cellular   jul         thu  ...         3    999         0
# 18464   cellular   jul         thu  ...         1    999         0
# 20072   cellular   aug         mon  ...         1    999         0
# 20531   cellular   aug         tue  ...         1    999         0
# 25183   cellular   nov         tue  ...         2    999         0
# 28476   cellular   apr         tue  ...         1    999         0
# 32505   cellular   may         fri  ...         4    999         0
# 36950   cellular   jul         thu  ...         1    999         0
# 38255  telephone   oct         tue  ...         1    999         0
#
#           poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 1265   nonexistent          1.1          93.994          -36.4      4.855
# 12260  nonexistent          1.4          93.918          -42.7      4.966
# 14155  nonexistent          1.4          93.918          -42.7      4.962
# 16819  nonexistent          1.4          93.918          -42.7      4.962
# 18464  nonexistent          1.4          93.918          -42.7      4.968
# 20072  nonexistent          1.4          93.444          -36.1      4.965
# 20531  nonexistent          1.4          93.444          -36.1      4.966
# 25183  nonexistent         -0.1          93.200          -42.0      4.153
# 28476  nonexistent         -1.8          93.075          -47.1      1.423
# 32505  nonexistent         -1.8          92.893          -46.2      1.313
# 36950  nonexistent         -2.9          92.469          -33.6      1.072
# 38255  nonexistent         -3.4          92.431          -26.9      0.742
#
#        nr.employed    y
# 1265        5191.0   no
# 12260       5228.1   no
# 14155       5228.1   no
# 16819       5228.1   no
# 18464       5228.1   no
# 20072       5228.1   no
# 20531       5228.1   no
# 25183       5195.8   no
# 28476       5099.1   no
# 32505       5099.1   no
# 36950       5076.2  yes
# 38255       5017.5   no
#
# [12 rows x 21 columns]

# %%
data_dup.shape
# Out:
# (12, 21)

# %%
data = data.drop_duplicates()
data.shape
# Out:
# (41176, 21)

# %% [markdown]
# ## Separating Explanatory and Target Variables

# %%
data_x = data.iloc[:, :-1]
print("Shape of X:", data_x.shape)
data_y = data["y"]
print("Shape of Y:", data_y.shape)
# Out:
# Shape of X: (41176, 20)
# Shape of Y: (41176,)

# %% [markdown]
# ## Splitting Train and Test Dataset

# %%
from sklearn.model_selection import train_test_split

X_rest, X_test, y_rest, y_test = train_test_split(data_x, data_y, test_size=0.2)
X_train, X_cv, y_train, y_cv = train_test_split(X_rest, y_rest, test_size=0.2)

print("X Train:", X_train.shape)
print("X CV:", X_cv.shape)
print("X Test:", X_test.shape)
print("Y Train:", y_train.shape)
print("Y CV:", y_cv.shape)
print("Y Test:", y_test.shape)
# Out:
# X Train: (26352, 20)
# X CV: (6588, 20)
# X Test: (8236, 20)
# Y Train: (26352,)
# Y CV: (6588,)
# Y Test: (8236,)

# %%
# Replace "no" with 0 and "yes" with 1

y_train.replace({"no":0, "yes":1}, inplace=True)
y_cv.replace({"no":0, "yes":1}, inplace=True)
y_test.replace({"no":0, "yes":1}, inplace=True)

# %% [markdown]
# ## ENCODING CATEGORICAL FEATURES
#
# ## One-Hot Encoding Categorical Features

# %%
# Categorical boolean mask
categorical_feature_mask = data_x.dtypes==object

# filter categorical columns using mask and turn it into a list
categorical_cols = data_x.columns[categorical_feature_mask].tolist()

# %%
categorical_cols
# Out:
# ['job',
#  'marital',
#  'education',
#  'default',
#  'housing',
#  'loan',
#  'contact',
#  'month',
#  'day_of_week',
#  'poutcome']

# %%
from sklearn.feature_extraction.text import CountVectorizer

def add_onehot_to_dataframe(sparse, df, vectorizer, name):
  '''
      This function will add the one hot encoded to the dataframe.

  '''
  for i, col in enumerate(vectorizer.get_feature_names()):
    colname = name+"_"+col
    # df[colname] = pd.SparseSeries(sparse[:, i].toarray().flatten(), fill_value=0)
    df[colname] = sparse[:, i].toarray().ravel().tolist()
  
  return df

def OneHotEncoder(categorical_cols, X_train, X_test, X_cv=None, include_cv=False):
  '''
    This function takes categorical column names as inputs. The objective
    of this function is to take the column names iteratively and encode the 
    features using One hot Encoding mechanism and also adding the encoded feature
    to the respective dataframe.

    The include_cv parameter indicates whether we should include CV dataset or not.
    This is added specifically because when using GridSearchCV or RandomizedSearchCV,
    we only split the dataset into train and test to give more data to training purposes.
    This is done because GridSearchCV splits the data internally anyway.
  '''

  for i in categorical_cols:
    Vectorizer = CountVectorizer(token_pattern="[A-Za-z0-9-.]+")
    print("Encoding for feature: ", i)
    # Encoding training dataset 
    temp_cols = Vectorizer.fit_transform(X_train[i])
    X_train = add_onehot_to_dataframe(temp_cols, X_train, Vectorizer, i)

    # Encoding Cross validation dataset
    if include_cv:
      temp_cols = Vectorizer.transform(X_cv[i])
      X_cv = add_onehot_to_dataframe(temp_cols, X_cv, Vectorizer, i)

    # Encoding Test dataset
    temp_cols = Vectorizer.transform(X_test[i])
    X_test = add_onehot_to_dataframe(temp_cols, X_test, Vectorizer, i)

# %%
OneHotEncoder(categorical_cols, X_train, X_test, X_cv, True)

# Drop the categorical features as the one hot encoded representation is present
X_train = X_train.drop(categorical_cols, axis=1)
X_cv = X_cv.drop(categorical_cols, axis=1)
X_test = X_test.drop(categorical_cols, axis=1)

print("Shape of train: ", X_train.shape)
print("Shape of CV: ", X_cv.shape)
print("Shape of test: ", X_test.shape)
# Out:
# Encoding for feature:  job
# Encoding for feature:  marital
# Encoding for feature:  education
# Encoding for feature:  default
# Encoding for feature:  housing
# Encoding for feature:  loan
# Encoding for feature:  contact
# Encoding for feature:  month
# Encoding for feature:  day_of_week
# Encoding for feature:  poutcome
# Shape of train:  (26352, 63)
# Shape of CV:  (6588, 63)
# Shape of test:  (8236, 63)

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26352 entries, 17884 to 6704
# Data columns (total 63 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   age                            26352 non-null  int64
#  1   duration                       26352 non-null  int64
#  2   campaign                       26352 non-null  int64
#  3   pdays                          26352 non-null  int64
#  4   previous                       26352 non-null  int64
#  5   emp.var.rate                   26352 non-null  float64
#  6   cons.price.idx                 26352 non-null  float64
#  7   cons.conf.idx                  26352 non-null  float64
#  8   euribor3m                      26352 non-null  float64
#  9   nr.employed                    26352 non-null  float64
#  10  job_admin.                     26352 non-null  int64
#  11  job_blue-collar                26352 non-null  int64
#  12  job_entrepreneur               26352 non-null  int64
#  13  job_housemaid                  26352 non-null  int64
#  14  job_management                 26352 non-null  int64
#  15  job_retired                    26352 non-null  int64
#  16  job_self-employed              26352 non-null  int64
#  17  job_services                   26352 non-null  int64
#  18  job_student                    26352 non-null  int64
#  19  job_technician                 26352 non-null  int64
#  20  job_unemployed                 26352 non-null  int64
#  21  job_unknown                    26352 non-null  int64
#  22  marital_divorced               26352 non-null  int64
#  23  marital_married                26352 non-null  int64
#  24  marital_single                 26352 non-null  int64
#  25  marital_unknown                26352 non-null  int64
#  26  education_basic.4y             26352 non-null  int64
#  27  education_basic.6y             26352 non-null  int64
#  28  education_basic.9y             26352 non-null  int64
#  29  education_high.school          26352 non-null  int64
#  30  education_illiterate           26352 non-null  int64
#  31  education_professional.course  26352 non-null  int64
#  32  education_university.degree    26352 non-null  int64
#  33  education_unknown              26352 non-null  int64
#  34  default_no                     26352 non-null  int64
#  35  default_unknown                26352 non-null  int64
#  36  default_yes                    26352 non-null  int64
#  37  housing_no                     26352 non-null  int64
#  38  housing_unknown                26352 non-null  int64
#  39  housing_yes                    26352 non-null  int64
#  40  loan_no                        26352 non-null  int64
#  41  loan_unknown                   26352 non-null  int64
#  42  loan_yes                       26352 non-null  int64
#  43  contact_cellular               26352 non-null  int64
#  44  contact_telephone              26352 non-null  int64
#  45  month_apr                      26352 non-null  int64
#  46  month_aug                      26352 non-null  int64
#  47  month_dec                      26352 non-null  int64
#  48  month_jul                      26352 non-null  int64
#  49  month_jun                      26352 non-null  int64
#  50  month_mar                      26352 non-null  int64
#  51  month_may                      26352 non-null  int64
#  52  month_nov                      26352 non-null  int64
#  53  month_oct                      26352 non-null  int64
#  54  month_sep                      26352 non-null  int64
#  55  day_of_week_fri                26352 non-null  int64
#  56  day_of_week_mon                26352 non-null  int64
#  57  day_of_week_thu                26352 non-null  int64
#  58  day_of_week_tue                26352 non-null  int64
#  59  day_of_week_wed                26352 non-null  int64
#  60  poutcome_failure               26352 non-null  int64
#  61  poutcome_nonexistent           26352 non-null  int64
#  62  poutcome_success               26352 non-null  int64
# dtypes: float64(5), int64(58)
# memory usage: 12.9 MB

# %%
# Removing duration feature 

# From Train
X_train = X_train.drop("duration", axis=1)
print("The shape of the train dataset: ", X_train.shape)

# From CV
X_cv = X_cv.drop("duration", axis=1)
print("The shape of the cv dataset: ", X_cv.shape)

# From Test
X_test = X_test.drop("duration", axis=1)
print("The shape of the test dataset: ", X_test.shape)
# Out:
# The shape of the train dataset:  (26352, 62)
# The shape of the cv dataset:  (6588, 62)
# The shape of the test dataset:  (8236, 62)

# %% [markdown]
# ## MODELLING THE DATA USING LINEAR SVM

# %%
# train the model on train set
model = SVC(kernel="linear")
model.fit(X_train, y_train)
  
# print prediction results
predictions = model.predict(X_test)
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.98      0.94      7304
#            1       0.61      0.20      0.30       932
#
#     accuracy                           0.89      8236
#    macro avg       0.76      0.59      0.62      8236
# weighted avg       0.87      0.89      0.87      8236

# %%
from sklearn import metrics
print("AUC score: ", metrics.roc_auc_score(y_test, predictions))
# Out:
# AUC score:  0.5687881486125898

# %%
# %matplotlib inline

alpha = [10 ** x for x in range(-5, 4)]
cv_auc_array=[]
for i in alpha:
    linearSVM = SGDClassifier(penalty='l2',alpha=i,class_weight='balanced')
    linearSVM.fit(X_train,y_train)
    sig_clf = CalibratedClassifierCV(linearSVM, method="sigmoid")
    sig_clf.fit(X_train, y_train)
    predict_y = sig_clf.predict_proba(X_cv)
    cv_auc_array.append(roc_auc_score(y_cv, predict_y[:,1]))
    
for i in range(len(cv_auc_array)):
    print ('AUC for alpha = ',alpha[i],'is',cv_auc_array[i])

best_alpha = np.argmax(cv_auc_array)
    
fig, ax = plt.subplots()
ax.plot(alpha, cv_auc_array,c='g')
for i, txt in enumerate(np.round(cv_auc_array,3)):
    ax.annotate((alpha[i],np.round(txt,3)), (alpha[i],cv_auc_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()

linearSVM = SGDClassifier(penalty='l2', alpha=alpha[best_alpha], class_weight='balanced')
linearSVM.fit(X_train,y_train)
sig_clf = CalibratedClassifierCV(linearSVM, method="sigmoid")
sig_clf.fit(X_train, y_train)
    
predict_y = sig_clf.predict_proba(X_train)
print ('For values of best alpha = ', alpha[best_alpha], "The train AUC is:",roc_auc_score(y_train, predict_y[:,1]))
predict_y = sig_clf.predict_proba(X_cv)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation AUC is:",roc_auc_score(y_cv, predict_y[:,1]))
predict_y = sig_clf.predict_proba(X_test)
print('For values of best alpha = ', alpha[best_alpha], "The test AUC is:",roc_auc_score(y_test, predict_y[:,1]))
# Out:
# AUC for alpha =  1e-05 is 0.5
# AUC for alpha =  0.0001 is 0.5
# AUC for alpha =  0.001 is 0.7614300398327045
# AUC for alpha =  0.01 is 0.760667872739846
# AUC for alpha =  0.1 is 0.7602294977276254
# AUC for alpha =  1 is 0.7546026012792029
# AUC for alpha =  10 is 0.7334025166089193
# AUC for alpha =  100 is 0.5427714987626837
# AUC for alpha =  1000 is 0.43430944836054475
# For values of best alpha =  0.001 The train AUC is: 0.7609872029458365
# For values of best alpha =  0.001 The cross validation AUC is: 0.759842920478997
# For values of best alpha =  0.001 The test AUC is: 0.7581192003767782

# %% [markdown]
# ## RBF

# %%
# %matplotlib inline
from sklearn.svm import SVC

alpha = [10 ** x for x in range(-5, 4)]
cv_auc_array=[]
for i in alpha:
    SVM = SVC(C=i,class_weight='balanced')
    SVM.fit(X_train,y_train)
    sig_clf = CalibratedClassifierCV(SVM, method="sigmoid")
    sig_clf.fit(X_train, y_train)
    predict_y = sig_clf.predict_proba(X_cv)
    cv_auc_array.append(roc_auc_score(y_cv, predict_y[:,1]))
    
for i in range(len(cv_auc_array)):
    print ('AUC for C = ',alpha[i],'is',cv_auc_array[i])

best_alpha = np.argmax(cv_auc_array)
    
fig, ax = plt.subplots()
ax.plot(alpha, cv_auc_array,c='g')
for i, txt in enumerate(np.round(cv_auc_array,3)):
    ax.annotate((alpha[i],np.round(txt,3)), (alpha[i],cv_auc_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()

SVM = SVC(C=alpha[best_alpha], class_weight='balanced')
SVM.fit(X_train,y_train)
sig_clf = CalibratedClassifierCV(SVM, method="sigmoid")
sig_clf.fit(X_train, y_train)
    
predict_y = sig_clf.predict_proba(X_train)
print ('For values of best alpha = ', alpha[best_alpha], "The train AUC is:",roc_auc_score(y_train, predict_y[:,1]))
predict_y = sig_clf.predict_proba(X_cv)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation AUC is:",roc_auc_score(y_cv, predict_y[:,1]))
predict_y = sig_clf.predict_proba(X_test)
print('For values of best alpha = ', alpha[best_alpha], "The test AUC is:",roc_auc_score(y_test, predict_y[:,1]))
# Out:
# AUC for C =  1e-05 is 0.7503953223255985
# AUC for C =  0.0001 is 0.7503953223255985
# AUC for C =  0.001 is 0.7503953223255985
# AUC for C =  0.01 is 0.7503953223255985
# AUC for C =  0.1 is 0.7575934176029878
# AUC for C =  1 is 0.7672022390984767
# AUC for C =  10 is 0.764903853484532
# AUC for C =  100 is 0.7682366247411233
# AUC for C =  1000 is 0.7711588258456042
# For values of best alpha =  1000 The train AUC is: 0.7712015527136709
# For values of best alpha =  1000 The cross validation AUC is: 0.7711588258456042
# For values of best alpha =  1000 The test AUC is: 0.7649196407254286

# %%
param_grid= {'C': [0.000001,0.00001,0.0001,0.001,0.01,1,10,100,1000],'gamma': [0.001,0.01,1],'kernel': ['linear','rbf']}
grid=GridSearchCV(SVC(),param_grid,refit=True,verbose=2,scoring="roc_auc")
grid.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# [CV] C=1e-06, gamma=0.001, kernel=linear .............................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] .............. C=1e-06, gamma=0.001, kernel=linear, total=  16.7s
# [CV] C=1e-06, gamma=0.001, kernel=linear .............................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   16.6s remaining:    0.0s
# [CV] .............. C=1e-06, gamma=0.001, kernel=linear, total=  16.3s
# [CV] C=1e-06, gamma=0.001, kernel=linear .............................
# [CV] .............. C=1e-06, gamma=0.001, kernel=linear, total=  14.3s
# [CV] C=1e-06, gamma=0.001, kernel=linear .............................
# [CV] .............. C=1e-06, gamma=0.001, kernel=linear, total=  17.2s
# [CV] C=1e-06, gamma=0.001, kernel=linear .............................
# [CV] .............. C=1e-06, gamma=0.001, kernel=linear, total=  15.8s
# [CV] C=1e-06, gamma=0.001, kernel=rbf ................................
# [CV] ................. C=1e-06, gamma=0.001, kernel=rbf, total=  21.2s
# [CV] C=1e-06, gamma=0.001, kernel=rbf ................................
# [CV] ................. C=1e-06, gamma=0.001, kernel=rbf, total=  20.7s
# [CV] C=1e-06, gamma=0.001, kernel=rbf ................................
# [CV] ................. C=1e-06, gamma=0.001, kernel=rbf, total=  21.0s
# [CV] C=1e-06, gamma=0.001, kernel=rbf ................................
# [CV] ................. C=1e-06, gamma=0.001, kernel=rbf, total=  20.8s
# [CV] C=1e-06, gamma=0.001, kernel=rbf ................................
# [CV] ................. C=1e-06, gamma=0.001, kernel=rbf, total=  20.8s
# [CV] C=1e-06, gamma=0.01, kernel=linear ..............................
# [CV] ............... C=1e-06, gamma=0.01, kernel=linear, total=  17.2s
# [CV] C=1e-06, gamma=0.01, kernel=linear ..............................
# [CV] ............... C=1e-06, gamma=0.01, kernel=linear, total=  16.4s
# [CV] C=1e-06, gamma=0.01, kernel=linear ..............................
# [CV] ............... C=1e-06, gamma=0.01, kernel=linear, total=  14.5s
# [CV] C=1e-06, gamma=0.01, kernel=linear ..............................
# [CV] ............... C=1e-06, gamma=0.01, kernel=linear, total=  17.1s
# [CV] C=1e-06, gamma=0.01, kernel=linear ..............................
# [CV] ............... C=1e-06, gamma=0.01, kernel=linear, total=  16.4s
# [CV] C=1e-06, gamma=0.01, kernel=rbf .................................
# [CV] .................. C=1e-06, gamma=0.01, kernel=rbf, total=  21.0s
# [CV] C=1e-06, gamma=0.01, kernel=rbf .................................
# [CV] .................. C=1e-06, gamma=0.01, kernel=rbf, total=  20.8s
# [CV] C=1e-06, gamma=0.01, kernel=rbf .................................
# [CV] .................. C=1e-06, gamma=0.01, kernel=rbf, total=  20.8s
# [CV] C=1e-06, gamma=0.01, kernel=rbf .................................
# [CV] .................. C=1e-06, gamma=0.01, kernel=rbf, total=  21.0s
# [CV] C=1e-06, gamma=0.01, kernel=rbf .................................
# [CV] .................. C=1e-06, gamma=0.01, kernel=rbf, total=  21.2s
# [CV] C=1e-06, gamma=1, kernel=linear .................................
# [CV] .................. C=1e-06, gamma=1, kernel=linear, total=  17.9s
# [CV] C=1e-06, gamma=1, kernel=linear .................................
# [CV] .................. C=1e-06, gamma=1, kernel=linear, total=  17.3s
# [CV] C=1e-06, gamma=1, kernel=linear .................................
# [CV] .................. C=1e-06, gamma=1, kernel=linear, total=  14.4s
# [CV] C=1e-06, gamma=1, kernel=linear .................................
# [CV] .................. C=1e-06, gamma=1, kernel=linear, total=  17.2s
# [CV] C=1e-06, gamma=1, kernel=linear .................................
# [CV] .................. C=1e-06, gamma=1, kernel=linear, total=  15.9s
# [CV] C=1e-06, gamma=1, kernel=rbf ....................................
# [CV] ..................... C=1e-06, gamma=1, kernel=rbf, total=  26.4s
# [CV] C=1e-06, gamma=1, kernel=rbf ....................................
# [CV] ..................... C=1e-06, gamma=1, kernel=rbf, total=  26.2s
# [CV] C=1e-06, gamma=1, kernel=rbf ....................................
# [CV] ..................... C=1e-06, gamma=1, kernel=rbf, total=  26.4s
# [CV] C=1e-06, gamma=1, kernel=rbf ....................................
# [CV] ..................... C=1e-06, gamma=1, kernel=rbf, total=  26.4s
# [CV] C=1e-06, gamma=1, kernel=rbf ....................................
# [CV] ..................... C=1e-06, gamma=1, kernel=rbf, total=  26.3s
# [CV] C=1e-05, gamma=0.001, kernel=linear .............................
# [CV] .............. C=1e-05, gamma=0.001, kernel=linear, total=  24.8s
# [CV] C=1e-05, gamma=0.001, kernel=linear .............................
# [CV] .............. C=1e-05, gamma=0.001, kernel=linear, total=  19.4s
# [CV] C=1e-05, gamma=0.001, kernel=linear .............................
# [CV] .............. C=1e-05, gamma=0.001, kernel=linear, total=  19.3s
# [CV] C=1e-05, gamma=0.001, kernel=linear .............................
# [CV] .............. C=1e-05, gamma=0.001, kernel=linear, total=  19.9s
# [CV] C=1e-05, gamma=0.001, kernel=linear .............................
# [CV] .............. C=1e-05, gamma=0.001, kernel=linear, total=  22.8s
# [CV] C=1e-05, gamma=0.001, kernel=rbf ................................
# [CV] ................. C=1e-05, gamma=0.001, kernel=rbf, total=  20.7s
# [CV] C=1e-05, gamma=0.001, kernel=rbf ................................
# [CV] ................. C=1e-05, gamma=0.001, kernel=rbf, total=  20.9s
# [CV] C=1e-05, gamma=0.001, kernel=rbf ................................
# [CV] ................. C=1e-05, gamma=0.001, kernel=rbf, total=  20.8s
# [CV] C=1e-05, gamma=0.001, kernel=rbf ................................
# [CV] ................. C=1e-05, gamma=0.001, kernel=rbf, total=  20.8s
# [CV] C=1e-05, gamma=0.001, kernel=rbf ................................
# [CV] ................. C=1e-05, gamma=0.001, kernel=rbf, total=  20.9s
# [CV] C=1e-05, gamma=0.01, kernel=linear ..............................
# [CV] ............... C=1e-05, gamma=0.01, kernel=linear, total=  24.7s
# [CV] C=1e-05, gamma=0.01, kernel=linear ..............................
# [CV] ............... C=1e-05, gamma=0.01, kernel=linear, total=  19.3s
# [CV] C=1e-05, gamma=0.01, kernel=linear ..............................
# [CV] ............... C=1e-05, gamma=0.01, kernel=linear, total=  19.0s
# [CV] C=1e-05, gamma=0.01, kernel=linear ..............................
# [CV] ............... C=1e-05, gamma=0.01, kernel=linear, total=  19.5s
# [CV] C=1e-05, gamma=0.01, kernel=linear ..............................
# [CV] ............... C=1e-05, gamma=0.01, kernel=linear, total=  22.6s
# [CV] C=1e-05, gamma=0.01, kernel=rbf .................................
# [CV] .................. C=1e-05, gamma=0.01, kernel=rbf, total=  20.8s
# [CV] C=1e-05, gamma=0.01, kernel=rbf .................................
# [CV] .................. C=1e-05, gamma=0.01, kernel=rbf, total=  21.2s
# [CV] C=1e-05, gamma=0.01, kernel=rbf .................................
# [CV] .................. C=1e-05, gamma=0.01, kernel=rbf, total=  20.8s
# [CV] C=1e-05, gamma=0.01, kernel=rbf .................................
# [CV] .................. C=1e-05, gamma=0.01, kernel=rbf, total=  20.8s
# [CV] C=1e-05, gamma=0.01, kernel=rbf .................................
# [CV] .................. C=1e-05, gamma=0.01, kernel=rbf, total=  21.1s
# [CV] C=1e-05, gamma=1, kernel=linear .................................
# [CV] .................. C=1e-05, gamma=1, kernel=linear, total=  24.9s
# [CV] C=1e-05, gamma=1, kernel=linear .................................
# [CV] .................. C=1e-05, gamma=1, kernel=linear, total=  19.3s
# [CV] C=1e-05, gamma=1, kernel=linear .................................
# [CV] .................. C=1e-05, gamma=1, kernel=linear, total=  19.3s
# [CV] C=1e-05, gamma=1, kernel=linear .................................
# [CV] .................. C=1e-05, gamma=1, kernel=linear, total=  19.2s
# [CV] C=1e-05, gamma=1, kernel=linear .................................
# [CV] .................. C=1e-05, gamma=1, kernel=linear, total=  22.6s
# [CV] C=1e-05, gamma=1, kernel=rbf ....................................
# [CV] ..................... C=1e-05, gamma=1, kernel=rbf, total=  26.5s
# [CV] C=1e-05, gamma=1, kernel=rbf ....................................
# [CV] ..................... C=1e-05, gamma=1, kernel=rbf, total=  26.4s
# [CV] C=1e-05, gamma=1, kernel=rbf ....................................
# [CV] ..................... C=1e-05, gamma=1, kernel=rbf, total=  26.3s
# [CV] C=1e-05, gamma=1, kernel=rbf ....................................
# [CV] ..................... C=1e-05, gamma=1, kernel=rbf, total=  26.4s
# [CV] C=1e-05, gamma=1, kernel=rbf ....................................
# [CV] ..................... C=1e-05, gamma=1, kernel=rbf, total=  26.2s
# [CV] C=0.0001, gamma=0.001, kernel=linear ............................
# [CV] ............. C=0.0001, gamma=0.001, kernel=linear, total=  26.9s
# [CV] C=0.0001, gamma=0.001, kernel=linear ............................
# [CV] ............. C=0.0001, gamma=0.001, kernel=linear, total=  18.8s
# [CV] C=0.0001, gamma=0.001, kernel=linear ............................
# [CV] ............. C=0.0001, gamma=0.001, kernel=linear, total=  20.1s
# [CV] C=0.0001, gamma=0.001, kernel=linear ............................
# [CV] ............. C=0.0001, gamma=0.001, kernel=linear, total=  20.5s
# [CV] C=0.0001, gamma=0.001, kernel=linear ............................
# [CV] ............. C=0.0001, gamma=0.001, kernel=linear, total=  19.7s
# [CV] C=0.0001, gamma=0.001, kernel=rbf ...............................
# [CV] ................ C=0.0001, gamma=0.001, kernel=rbf, total=  20.8s
# [CV] C=0.0001, gamma=0.001, kernel=rbf ...............................
# [CV] ................ C=0.0001, gamma=0.001, kernel=rbf, total=  20.9s
# [CV] C=0.0001, gamma=0.001, kernel=rbf ...............................
# [CV] ................ C=0.0001, gamma=0.001, kernel=rbf, total=  20.8s
# [CV] C=0.0001, gamma=0.001, kernel=rbf ...............................
# [CV] ................ C=0.0001, gamma=0.001, kernel=rbf, total=  20.7s
# [CV] C=0.0001, gamma=0.001, kernel=rbf ...............................
# [CV] ................ C=0.0001, gamma=0.001, kernel=rbf, total=  20.9s
# [CV] C=0.0001, gamma=0.01, kernel=linear .............................
# [CV] .............. C=0.0001, gamma=0.01, kernel=linear, total=  26.5s
# [CV] C=0.0001, gamma=0.01, kernel=linear .............................
# [CV] .............. C=0.0001, gamma=0.01, kernel=linear, total=  18.7s
# [CV] C=0.0001, gamma=0.01, kernel=linear .............................
# [CV] .............. C=0.0001, gamma=0.01, kernel=linear, total=  19.9s
# [CV] C=0.0001, gamma=0.01, kernel=linear .............................
# [CV] .............. C=0.0001, gamma=0.01, kernel=linear, total=  20.6s
# [CV] C=0.0001, gamma=0.01, kernel=linear .............................
# [CV] .............. C=0.0001, gamma=0.01, kernel=linear, total=  19.7s
# [CV] C=0.0001, gamma=0.01, kernel=rbf ................................
# [CV] ................. C=0.0001, gamma=0.01, kernel=rbf, total=  21.0s
# [CV] C=0.0001, gamma=0.01, kernel=rbf ................................
# [CV] ................. C=0.0001, gamma=0.01, kernel=rbf, total=  21.0s
# [CV] C=0.0001, gamma=0.01, kernel=rbf ................................
# [CV] ................. C=0.0001, gamma=0.01, kernel=rbf, total=  20.8s
# [CV] C=0.0001, gamma=0.01, kernel=rbf ................................
# [CV] ................. C=0.0001, gamma=0.01, kernel=rbf, total=  20.8s
# [CV] C=0.0001, gamma=0.01, kernel=rbf ................................
# [CV] ................. C=0.0001, gamma=0.01, kernel=rbf, total=  21.1s
# [CV] C=0.0001, gamma=1, kernel=linear ................................
# [CV] ................. C=0.0001, gamma=1, kernel=linear, total=  26.6s
# [CV] C=0.0001, gamma=1, kernel=linear ................................
# [CV] ................. C=0.0001, gamma=1, kernel=linear, total=  19.1s
# [CV] C=0.0001, gamma=1, kernel=linear ................................
# [CV] ................. C=0.0001, gamma=1, kernel=linear, total=  19.7s
# [CV] C=0.0001, gamma=1, kernel=linear ................................
# [CV] ................. C=0.0001, gamma=1, kernel=linear, total=  20.6s
# [CV] C=0.0001, gamma=1, kernel=linear ................................
# [CV] ................. C=0.0001, gamma=1, kernel=linear, total=  19.9s
# [CV] C=0.0001, gamma=1, kernel=rbf ...................................
# [CV] .................... C=0.0001, gamma=1, kernel=rbf, total=  26.4s
# [CV] C=0.0001, gamma=1, kernel=rbf ...................................
# [CV] .................... C=0.0001, gamma=1, kernel=rbf, total=  26.4s
# [CV] C=0.0001, gamma=1, kernel=rbf ...................................
# [CV] .................... C=0.0001, gamma=1, kernel=rbf, total=  26.3s
# [CV] C=0.0001, gamma=1, kernel=rbf ...................................
# [CV] .................... C=0.0001, gamma=1, kernel=rbf, total=  26.5s
# [CV] C=0.0001, gamma=1, kernel=rbf ...................................
# [CV] .................... C=0.0001, gamma=1, kernel=rbf, total=  26.5s
# [CV] C=0.001, gamma=0.001, kernel=linear .............................
# [CV] .............. C=0.001, gamma=0.001, kernel=linear, total=  23.7s
# [CV] C=0.001, gamma=0.001, kernel=linear .............................
# [CV] .............. C=0.001, gamma=0.001, kernel=linear, total=  20.1s
# [CV] C=0.001, gamma=0.001, kernel=linear .............................
# [CV] .............. C=0.001, gamma=0.001, kernel=linear, total=  21.8s
# [CV] C=0.001, gamma=0.001, kernel=linear .............................
# [CV] .............. C=0.001, gamma=0.001, kernel=linear, total=  28.1s
# [CV] C=0.001, gamma=0.001, kernel=linear .............................
# [CV] .............. C=0.001, gamma=0.001, kernel=linear, total=  22.6s
# [CV] C=0.001, gamma=0.001, kernel=rbf ................................
# [CV] ................. C=0.001, gamma=0.001, kernel=rbf, total=  22.0s
# [CV] C=0.001, gamma=0.001, kernel=rbf ................................
# [CV] ................. C=0.001, gamma=0.001, kernel=rbf, total=  22.6s
# [CV] C=0.001, gamma=0.001, kernel=rbf ................................
# [CV] ................. C=0.001, gamma=0.001, kernel=rbf, total=  22.1s
# [CV] C=0.001, gamma=0.001, kernel=rbf ................................
# [CV] ................. C=0.001, gamma=0.001, kernel=rbf, total=  22.1s
# [CV] C=0.001, gamma=0.001, kernel=rbf ................................
# [CV] ................. C=0.001, gamma=0.001, kernel=rbf, total=  22.3s
# [CV] C=0.001, gamma=0.01, kernel=linear ..............................
# [CV] ............... C=0.001, gamma=0.01, kernel=linear, total=  23.6s
# [CV] C=0.001, gamma=0.01, kernel=linear ..............................
# [CV] ............... C=0.001, gamma=0.01, kernel=linear, total=  20.4s
# [CV] C=0.001, gamma=0.01, kernel=linear ..............................
# [CV] ............... C=0.001, gamma=0.01, kernel=linear, total=  21.7s
# [CV] C=0.001, gamma=0.01, kernel=linear ..............................
# [CV] ............... C=0.001, gamma=0.01, kernel=linear, total=  28.5s
# [CV] C=0.001, gamma=0.01, kernel=linear ..............................
# [CV] ............... C=0.001, gamma=0.01, kernel=linear, total=  22.2s
# [CV] C=0.001, gamma=0.01, kernel=rbf .................................
# [CV] .................. C=0.001, gamma=0.01, kernel=rbf, total=  21.0s
# [CV] C=0.001, gamma=0.01, kernel=rbf .................................
# [CV] .................. C=0.001, gamma=0.01, kernel=rbf, total=  21.1s
# [CV] C=0.001, gamma=0.01, kernel=rbf .................................
# [CV] .................. C=0.001, gamma=0.01, kernel=rbf, total=  21.0s
# [CV] C=0.001, gamma=0.01, kernel=rbf .................................
# [CV] .................. C=0.001, gamma=0.01, kernel=rbf, total=  21.0s
# [CV] C=0.001, gamma=0.01, kernel=rbf .................................
# [CV] .................. C=0.001, gamma=0.01, kernel=rbf, total=  21.1s
# [CV] C=0.001, gamma=1, kernel=linear .................................
# [CV] .................. C=0.001, gamma=1, kernel=linear, total=  23.8s
# [CV] C=0.001, gamma=1, kernel=linear .................................
# [CV] .................. C=0.001, gamma=1, kernel=linear, total=  20.1s
# [CV] C=0.001, gamma=1, kernel=linear .................................
# [CV] .................. C=0.001, gamma=1, kernel=linear, total=  21.8s
# [CV] C=0.001, gamma=1, kernel=linear .................................
# [CV] .................. C=0.001, gamma=1, kernel=linear, total=  28.5s
# [CV] C=0.001, gamma=1, kernel=linear .................................
# [CV] .................. C=0.001, gamma=1, kernel=linear, total=  22.3s
# [CV] C=0.001, gamma=1, kernel=rbf ....................................
# [CV] ..................... C=0.001, gamma=1, kernel=rbf, total=  26.6s
# [CV] C=0.001, gamma=1, kernel=rbf ....................................
# [CV] ..................... C=0.001, gamma=1, kernel=rbf, total=  26.5s
# [CV] C=0.001, gamma=1, kernel=rbf ....................................
# [CV] ..................... C=0.001, gamma=1, kernel=rbf, total=  26.6s
# [CV] C=0.001, gamma=1, kernel=rbf ....................................
# [CV] ..................... C=0.001, gamma=1, kernel=rbf, total=  26.5s
# [CV] C=0.001, gamma=1, kernel=rbf ....................................
# [CV] ..................... C=0.001, gamma=1, kernel=rbf, total=  26.4s
# [CV] C=0.01, gamma=0.001, kernel=linear ..............................
# [CV] ............... C=0.01, gamma=0.001, kernel=linear, total=  23.2s
# [CV] C=0.01, gamma=0.001, kernel=linear ..............................
# [CV] ............... C=0.01, gamma=0.001, kernel=linear, total=  17.7s
# [CV] C=0.01, gamma=0.001, kernel=linear ..............................
# [CV] ............... C=0.01, gamma=0.001, kernel=linear, total=  22.1s
# [CV] C=0.01, gamma=0.001, kernel=linear ..............................
# [CV] ............... C=0.01, gamma=0.001, kernel=linear, total=  20.1s
# [CV] C=0.01, gamma=0.001, kernel=linear ..............................
# [CV] ............... C=0.01, gamma=0.001, kernel=linear, total=  21.6s
# [CV] C=0.01, gamma=0.001, kernel=rbf .................................
# [CV] .................. C=0.01, gamma=0.001, kernel=rbf, total=  27.1s
# [CV] C=0.01, gamma=0.001, kernel=rbf .................................
# [CV] .................. C=0.01, gamma=0.001, kernel=rbf, total=  27.5s
# [CV] C=0.01, gamma=0.001, kernel=rbf .................................
# [CV] .................. C=0.01, gamma=0.001, kernel=rbf, total=  27.2s
# [CV] C=0.01, gamma=0.001, kernel=rbf .................................
# [CV] .................. C=0.01, gamma=0.001, kernel=rbf, total=  27.7s
# [CV] C=0.01, gamma=0.001, kernel=rbf .................................
# [CV] .................. C=0.01, gamma=0.001, kernel=rbf, total=  27.5s
# [CV] C=0.01, gamma=0.01, kernel=linear ...............................
# [CV] ................ C=0.01, gamma=0.01, kernel=linear, total=  23.2s
# [CV] C=0.01, gamma=0.01, kernel=linear ...............................
# [CV] ................ C=0.01, gamma=0.01, kernel=linear, total=  17.6s
# [CV] C=0.01, gamma=0.01, kernel=linear ...............................
# [CV] ................ C=0.01, gamma=0.01, kernel=linear, total=  22.0s
# [CV] C=0.01, gamma=0.01, kernel=linear ...............................
# [CV] ................ C=0.01, gamma=0.01, kernel=linear, total=  20.4s
# [CV] C=0.01, gamma=0.01, kernel=linear ...............................
# [CV] ................ C=0.01, gamma=0.01, kernel=linear, total=  21.4s
# [CV] C=0.01, gamma=0.01, kernel=rbf ..................................
# [CV] ................... C=0.01, gamma=0.01, kernel=rbf, total=  25.2s
# [CV] C=0.01, gamma=0.01, kernel=rbf ..................................
# [CV] ................... C=0.01, gamma=0.01, kernel=rbf, total=  25.5s
# [CV] C=0.01, gamma=0.01, kernel=rbf ..................................
# [CV] ................... C=0.01, gamma=0.01, kernel=rbf, total=  25.7s
# [CV] C=0.01, gamma=0.01, kernel=rbf ..................................
# [CV] ................... C=0.01, gamma=0.01, kernel=rbf, total=  25.2s
# [CV] C=0.01, gamma=0.01, kernel=rbf ..................................
# [CV] ................... C=0.01, gamma=0.01, kernel=rbf, total=  25.1s
# [CV] C=0.01, gamma=1, kernel=linear ..................................
# [CV] ................... C=0.01, gamma=1, kernel=linear, total=  22.8s
# [CV] C=0.01, gamma=1, kernel=linear ..................................
# [CV] ................... C=0.01, gamma=1, kernel=linear, total=  17.7s
# [CV] C=0.01, gamma=1, kernel=linear ..................................
# [CV] ................... C=0.01, gamma=1, kernel=linear, total=  22.4s
# [CV] C=0.01, gamma=1, kernel=linear ..................................
# [CV] ................... C=0.01, gamma=1, kernel=linear, total=  20.1s
# [CV] C=0.01, gamma=1, kernel=linear ..................................
# [CV] ................... C=0.01, gamma=1, kernel=linear, total=  21.6s
# [CV] C=0.01, gamma=1, kernel=rbf .....................................
# [CV] ...................... C=0.01, gamma=1, kernel=rbf, total= 2.8min
# [CV] C=0.01, gamma=1, kernel=rbf .....................................
# [CV] ...................... C=0.01, gamma=1, kernel=rbf, total= 2.8min
# [CV] C=0.01, gamma=1, kernel=rbf .....................................
# [CV] ...................... C=0.01, gamma=1, kernel=rbf, total= 2.8min
# [CV] C=0.01, gamma=1, kernel=rbf .....................................
# [CV] ...................... C=0.01, gamma=1, kernel=rbf, total= 2.8min
# [CV] C=0.01, gamma=1, kernel=rbf .....................................
# [CV] ...................... C=0.01, gamma=1, kernel=rbf, total= 2.8min
# [CV] C=1, gamma=0.001, kernel=linear .................................
# [CV] .................. C=1, gamma=0.001, kernel=linear, total=  22.2s
# [CV] C=1, gamma=0.001, kernel=linear .................................
# [CV] .................. C=1, gamma=0.001, kernel=linear, total=  18.8s
# [CV] C=1, gamma=0.001, kernel=linear .................................
# [CV] .................. C=1, gamma=0.001, kernel=linear, total=  17.8s
# [CV] C=1, gamma=0.001, kernel=linear .................................
# [CV] .................. C=1, gamma=0.001, kernel=linear, total=  20.4s
# [CV] C=1, gamma=0.001, kernel=linear .................................
# [CV] .................. C=1, gamma=0.001, kernel=linear, total=  18.0s
# [CV] C=1, gamma=0.001, kernel=rbf ....................................
# [CV] ..................... C=1, gamma=0.001, kernel=rbf, total=  34.1s
# [CV] C=1, gamma=0.001, kernel=rbf ....................................
# [CV] ..................... C=1, gamma=0.001, kernel=rbf, total=  32.4s
# [CV] C=1, gamma=0.001, kernel=rbf ....................................
# [CV] ..................... C=1, gamma=0.001, kernel=rbf, total=  32.4s
# [CV] C=1, gamma=0.001, kernel=rbf ....................................
# [CV] ..................... C=1, gamma=0.001, kernel=rbf, total=  32.5s
# [CV] C=1, gamma=0.001, kernel=rbf ....................................
# [CV] ..................... C=1, gamma=0.001, kernel=rbf, total=  41.9s
# [CV] C=1, gamma=0.01, kernel=linear ..................................
# [CV] ................... C=1, gamma=0.01, kernel=linear, total=  21.9s
# [CV] C=1, gamma=0.01, kernel=linear ..................................
# [CV] ................... C=1, gamma=0.01, kernel=linear, total=  19.1s
# [CV] C=1, gamma=0.01, kernel=linear ..................................
# [CV] ................... C=1, gamma=0.01, kernel=linear, total=  17.8s
# [CV] C=1, gamma=0.01, kernel=linear ..................................
# [CV] ................... C=1, gamma=0.01, kernel=linear, total=  20.4s
# [CV] C=1, gamma=0.01, kernel=linear ..................................
# [CV] ................... C=1, gamma=0.01, kernel=linear, total=  18.2s
# [CV] C=1, gamma=0.01, kernel=rbf .....................................
# [CV] ...................... C=1, gamma=0.01, kernel=rbf, total= 1.2min
# [CV] C=1, gamma=0.01, kernel=rbf .....................................
# [CV] ...................... C=1, gamma=0.01, kernel=rbf, total= 1.2min
# [CV] C=1, gamma=0.01, kernel=rbf .....................................
# [CV] ...................... C=1, gamma=0.01, kernel=rbf, total= 1.3min
# [CV] C=1, gamma=0.01, kernel=rbf .....................................
# [CV] ...................... C=1, gamma=0.01, kernel=rbf, total= 1.6min
# [CV] C=1, gamma=0.01, kernel=rbf .....................................
# [CV] ...................... C=1, gamma=0.01, kernel=rbf, total= 1.3min
# [CV] C=1, gamma=1, kernel=linear .....................................
# [CV] ...................... C=1, gamma=1, kernel=linear, total=  21.8s
# [CV] C=1, gamma=1, kernel=linear .....................................
# [CV] ...................... C=1, gamma=1, kernel=linear, total=  18.7s
# [CV] C=1, gamma=1, kernel=linear .....................................
# [CV] ...................... C=1, gamma=1, kernel=linear, total=  17.9s
# [CV] C=1, gamma=1, kernel=linear .....................................
# [CV] ...................... C=1, gamma=1, kernel=linear, total=  20.7s
# [CV] C=1, gamma=1, kernel=linear .....................................
# [CV] ...................... C=1, gamma=1, kernel=linear, total=  17.9s
# [CV] C=1, gamma=1, kernel=rbf ........................................
# [CV] ......................... C=1, gamma=1, kernel=rbf, total= 4.8min
# [CV] C=1, gamma=1, kernel=rbf ........................................
# [CV] ......................... C=1, gamma=1, kernel=rbf, total= 4.9min
# [CV] C=1, gamma=1, kernel=rbf ........................................
# [CV] ......................... C=1, gamma=1, kernel=rbf, total= 4.9min
# [CV] C=1, gamma=1, kernel=rbf ........................................
# [CV] ......................... C=1, gamma=1, kernel=rbf, total= 4.8min
# [CV] C=1, gamma=1, kernel=rbf ........................................
# [CV] ......................... C=1, gamma=1, kernel=rbf, total= 4.8min
# [CV] C=10, gamma=0.001, kernel=linear ................................
# [CV] ................. C=10, gamma=0.001, kernel=linear, total=  21.7s
# [CV] C=10, gamma=0.001, kernel=linear ................................
# [CV] ................. C=10, gamma=0.001, kernel=linear, total=  25.0s
# [CV] C=10, gamma=0.001, kernel=linear ................................
# [CV] ................. C=10, gamma=0.001, kernel=linear, total=  21.1s
# [CV] C=10, gamma=0.001, kernel=linear ................................
# [CV] ................. C=10, gamma=0.001, kernel=linear, total=  23.9s
# [CV] C=10, gamma=0.001, kernel=linear ................................
# [CV] ................. C=10, gamma=0.001, kernel=linear, total=  25.3s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] .................... C=10, gamma=0.001, kernel=rbf, total= 1.5min
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] .................... C=10, gamma=0.001, kernel=rbf, total= 1.4min
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] .................... C=10, gamma=0.001, kernel=rbf, total= 1.4min
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] .................... C=10, gamma=0.001, kernel=rbf, total= 1.3min
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] .................... C=10, gamma=0.001, kernel=rbf, total= 1.5min
# [CV] C=10, gamma=0.01, kernel=linear .................................
# [CV] .................. C=10, gamma=0.01, kernel=linear, total=  21.6s
# [CV] C=10, gamma=0.01, kernel=linear .................................
# [CV] .................. C=10, gamma=0.01, kernel=linear, total=  24.9s
# [CV] C=10, gamma=0.01, kernel=linear .................................
# [CV] .................. C=10, gamma=0.01, kernel=linear, total=  21.1s
# [CV] C=10, gamma=0.01, kernel=linear .................................
# [CV] .................. C=10, gamma=0.01, kernel=linear, total=  24.1s
# [CV] C=10, gamma=0.01, kernel=linear .................................
# [CV] .................. C=10, gamma=0.01, kernel=linear, total=  25.2s
# [CV] C=10, gamma=0.01, kernel=rbf ....................................
# [CV] ..................... C=10, gamma=0.01, kernel=rbf, total= 2.0min
# [CV] C=10, gamma=0.01, kernel=rbf ....................................
# [CV] ..................... C=10, gamma=0.01, kernel=rbf, total= 2.0min
# [CV] C=10, gamma=0.01, kernel=rbf ....................................
# [CV] ..................... C=10, gamma=0.01, kernel=rbf, total= 2.0min
# [CV] C=10, gamma=0.01, kernel=rbf ....................................
# [CV] ..................... C=10, gamma=0.01, kernel=rbf, total= 2.1min
# [CV] C=10, gamma=0.01, kernel=rbf ....................................
# [CV] ..................... C=10, gamma=0.01, kernel=rbf, total= 2.1min
# [CV] C=10, gamma=1, kernel=linear ....................................
# [CV] ..................... C=10, gamma=1, kernel=linear, total=  21.9s
# [CV] C=10, gamma=1, kernel=linear ....................................
# [CV] ..................... C=10, gamma=1, kernel=linear, total=  24.5s
# [CV] C=10, gamma=1, kernel=linear ....................................
# [CV] ..................... C=10, gamma=1, kernel=linear, total=  21.4s
# [CV] C=10, gamma=1, kernel=linear ....................................
# [CV] ..................... C=10, gamma=1, kernel=linear, total=  23.7s
# [CV] C=10, gamma=1, kernel=linear ....................................
# [CV] ..................... C=10, gamma=1, kernel=linear, total=  25.3s
# [CV] C=10, gamma=1, kernel=rbf .......................................
# [CV] ........................ C=10, gamma=1, kernel=rbf, total= 6.0min
# [CV] C=10, gamma=1, kernel=rbf .......................................
# [CV] ........................ C=10, gamma=1, kernel=rbf, total= 6.1min
# [CV] C=10, gamma=1, kernel=rbf .......................................
# [CV] ........................ C=10, gamma=1, kernel=rbf, total= 6.1min
# [CV] C=10, gamma=1, kernel=rbf .......................................
# [CV] ........................ C=10, gamma=1, kernel=rbf, total= 6.1min
# [CV] C=10, gamma=1, kernel=rbf .......................................
# [CV] ........................ C=10, gamma=1, kernel=rbf, total= 6.1min
# [CV] C=100, gamma=0.001, kernel=linear ...............................
# [CV] ................ C=100, gamma=0.001, kernel=linear, total=  18.6s
# [CV] C=100, gamma=0.001, kernel=linear ...............................
# [CV] ................ C=100, gamma=0.001, kernel=linear, total=  16.7s
# [CV] C=100, gamma=0.001, kernel=linear ...............................
# [CV] ................ C=100, gamma=0.001, kernel=linear, total=  26.2s
# [CV] C=100, gamma=0.001, kernel=linear ...............................
# [CV] ................ C=100, gamma=0.001, kernel=linear, total=  21.6s
# [CV] C=100, gamma=0.001, kernel=linear ...............................
# [CV] ................ C=100, gamma=0.001, kernel=linear, total=  24.3s
# [CV] C=100, gamma=0.001, kernel=rbf ..................................
# [CV] ................... C=100, gamma=0.001, kernel=rbf, total= 3.7min
# [CV] C=100, gamma=0.001, kernel=rbf ..................................
# [CV] ................... C=100, gamma=0.001, kernel=rbf, total= 3.9min
# [CV] C=100, gamma=0.001, kernel=rbf ..................................
# [CV] ................... C=100, gamma=0.001, kernel=rbf, total= 3.8min
# [CV] C=100, gamma=0.001, kernel=rbf ..................................
# [CV] ................... C=100, gamma=0.001, kernel=rbf, total= 4.0min
# [CV] C=100, gamma=0.001, kernel=rbf ..................................
# [CV] ................... C=100, gamma=0.001, kernel=rbf, total= 3.9min
# [CV] C=100, gamma=0.01, kernel=linear ................................
# [CV] ................. C=100, gamma=0.01, kernel=linear, total=  18.5s
# [CV] C=100, gamma=0.01, kernel=linear ................................
# [CV] ................. C=100, gamma=0.01, kernel=linear, total=  16.7s
# [CV] C=100, gamma=0.01, kernel=linear ................................
# [CV] ................. C=100, gamma=0.01, kernel=linear, total=  26.2s
# [CV] C=100, gamma=0.01, kernel=linear ................................
# [CV] ................. C=100, gamma=0.01, kernel=linear, total=  21.7s
# [CV] C=100, gamma=0.01, kernel=linear ................................
# [CV] ................. C=100, gamma=0.01, kernel=linear, total=  24.4s
# [CV] C=100, gamma=0.01, kernel=rbf ...................................
# [CV] .................... C=100, gamma=0.01, kernel=rbf, total= 3.1min
# [CV] C=100, gamma=0.01, kernel=rbf ...................................
# [CV] .................... C=100, gamma=0.01, kernel=rbf, total= 3.0min
# [CV] C=100, gamma=0.01, kernel=rbf ...................................
# [CV] .................... C=100, gamma=0.01, kernel=rbf, total= 3.1min
# [CV] C=100, gamma=0.01, kernel=rbf ...................................
# [CV] .................... C=100, gamma=0.01, kernel=rbf, total= 3.2min
# [CV] C=100, gamma=0.01, kernel=rbf ...................................
# [CV] .................... C=100, gamma=0.01, kernel=rbf, total= 3.2min
# [CV] C=100, gamma=1, kernel=linear ...................................
# [CV] .................... C=100, gamma=1, kernel=linear, total=  18.4s
# [CV] C=100, gamma=1, kernel=linear ...................................
# [CV] .................... C=100, gamma=1, kernel=linear, total=  16.6s
# [CV] C=100, gamma=1, kernel=linear ...................................
# [CV] .................... C=100, gamma=1, kernel=linear, total=  26.1s
# [CV] C=100, gamma=1, kernel=linear ...................................
# [CV] .................... C=100, gamma=1, kernel=linear, total=  21.4s
# [CV] C=100, gamma=1, kernel=linear ...................................
# [CV] .................... C=100, gamma=1, kernel=linear, total=  24.3s
# [CV] C=100, gamma=1, kernel=rbf ......................................
# [CV] ....................... C=100, gamma=1, kernel=rbf, total= 7.9min
# [CV] C=100, gamma=1, kernel=rbf ......................................
# [CV] ....................... C=100, gamma=1, kernel=rbf, total= 6.1min
# [CV] C=100, gamma=1, kernel=rbf ......................................
# [CV] ....................... C=100, gamma=1, kernel=rbf, total= 6.0min
# [CV] C=100, gamma=1, kernel=rbf ......................................
# [CV] ....................... C=100, gamma=1, kernel=rbf, total= 6.0min
# [CV] C=100, gamma=1, kernel=rbf ......................................
# [CV] ....................... C=100, gamma=1, kernel=rbf, total= 8.3min
# [CV] C=1000, gamma=0.001, kernel=linear ..............................
# [CV] ............... C=1000, gamma=0.001, kernel=linear, total=  18.5s
# [CV] C=1000, gamma=0.001, kernel=linear ..............................
# [CV] ............... C=1000, gamma=0.001, kernel=linear, total=  18.1s
# [CV] C=1000, gamma=0.001, kernel=linear ..............................
# [CV] ............... C=1000, gamma=0.001, kernel=linear, total=  17.1s
# [CV] C=1000, gamma=0.001, kernel=linear ..............................
# [CV] ............... C=1000, gamma=0.001, kernel=linear, total=  20.7s
# [CV] C=1000, gamma=0.001, kernel=linear ..............................
# [CV] ............... C=1000, gamma=0.001, kernel=linear, total=  20.7s
# [CV] C=1000, gamma=0.001, kernel=rbf .................................
# [CV] .................. C=1000, gamma=0.001, kernel=rbf, total= 9.5min
# [CV] C=1000, gamma=0.001, kernel=rbf .................................
# [CV] .................. C=1000, gamma=0.001, kernel=rbf, total= 9.7min
# [CV] C=1000, gamma=0.001, kernel=rbf .................................
# [CV] .................. C=1000, gamma=0.001, kernel=rbf, total= 9.7min
# [CV] C=1000, gamma=0.001, kernel=rbf .................................
# [CV] .................. C=1000, gamma=0.001, kernel=rbf, total= 9.5min
# [CV] C=1000, gamma=0.001, kernel=rbf .................................
# [CV] .................. C=1000, gamma=0.001, kernel=rbf, total= 9.8min
# [CV] C=1000, gamma=0.01, kernel=linear ...............................
# [CV] ................ C=1000, gamma=0.01, kernel=linear, total=  19.0s
# [CV] C=1000, gamma=0.01, kernel=linear ...............................
# [CV] ................ C=1000, gamma=0.01, kernel=linear, total=  19.0s
# [CV] C=1000, gamma=0.01, kernel=linear ...............................
# [CV] ................ C=1000, gamma=0.01, kernel=linear, total=  17.8s
# [CV] C=1000, gamma=0.01, kernel=linear ...............................
# [CV] ................ C=1000, gamma=0.01, kernel=linear, total=  20.8s
# [CV] C=1000, gamma=0.01, kernel=linear ...............................
# [CV] ................ C=1000, gamma=0.01, kernel=linear, total=  20.5s
# [CV] C=1000, gamma=0.01, kernel=rbf ..................................
# [CV] ................... C=1000, gamma=0.01, kernel=rbf, total= 5.4min
# [CV] C=1000, gamma=0.01, kernel=rbf ..................................
# [CV] ................... C=1000, gamma=0.01, kernel=rbf, total= 5.8min
# [CV] C=1000, gamma=0.01, kernel=rbf ..................................
# [CV] ................... C=1000, gamma=0.01, kernel=rbf, total= 6.2min
# [CV] C=1000, gamma=0.01, kernel=rbf ..................................
# [CV] ................... C=1000, gamma=0.01, kernel=rbf, total= 6.2min
# [CV] C=1000, gamma=0.01, kernel=rbf ..................................
# [CV] ................... C=1000, gamma=0.01, kernel=rbf, total= 5.3min
# [CV] C=1000, gamma=1, kernel=linear ..................................
# [CV] ................... C=1000, gamma=1, kernel=linear, total=  18.4s
# [CV] C=1000, gamma=1, kernel=linear ..................................
# [CV] ................... C=1000, gamma=1, kernel=linear, total=  18.4s
# [CV] C=1000, gamma=1, kernel=linear ..................................
# [CV] ................... C=1000, gamma=1, kernel=linear, total=  17.2s
# [CV] C=1000, gamma=1, kernel=linear ..................................
# [CV] ................... C=1000, gamma=1, kernel=linear, total=  21.2s
# [CV] C=1000, gamma=1, kernel=linear ..................................
# [CV] ................... C=1000, gamma=1, kernel=linear, total=  20.7s
# [CV] C=1000, gamma=1, kernel=rbf .....................................
# [CV] ...................... C=1000, gamma=1, kernel=rbf, total= 6.2min
# [CV] C=1000, gamma=1, kernel=rbf .....................................
# [CV] ...................... C=1000, gamma=1, kernel=rbf, total= 6.2min
# [CV] C=1000, gamma=1, kernel=rbf .....................................
# [CV] ...................... C=1000, gamma=1, kernel=rbf, total= 6.2min
# [CV] C=1000, gamma=1, kernel=rbf .....................................
# [CV] ...................... C=1000, gamma=1, kernel=rbf, total= 6.1min
# [CV] C=1000, gamma=1, kernel=rbf .....................................
# [CV] ...................... C=1000, gamma=1, kernel=rbf, total= 6.1min
# [Parallel(n_jobs=1)]: Done 270 out of 270 | elapsed: 346.7min finished
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [1e-06, 1e-05, 0.0001, 0.001, 0.01, 1, 10, 100,
#                                1000],
#                          'gamma': [0.001, 0.01, 1],
#                          'kernel': ['linear', 'rbf']},
#              scoring='roc_auc', verbose=2)

# %%
print(grid.best_estimator_)
# Out:
# SVC(C=0.01, gamma=0.001, kernel='linear')

# %%
SVM1 = SVC(C=0.01,gamma=0.001,kernel='linear', class_weight='balanced')
SVM1.fit(X_train,y_train)
clf = CalibratedClassifierCV(SVM1, method="sigmoid")
clf.fit(X_train, y_train)
    
pred_y = clf.predict_proba(X_train)
print ("The train AUC is:",roc_auc_score(y_train, pred_y[:,1]))
pred_y = clf.predict_proba(X_cv)
print("The cross validation AUC is:",roc_auc_score(y_cv, pred_y[:,1]))
pred_y = clf.predict_proba(X_test)
print("The test AUC is:",roc_auc_score(y_test, pred_y[:,1]))
# Out:
# The train AUC is: 0.7857016547583836
# The cross validation AUC is: 0.7577914236412637
# The test AUC is: 0.7888345471233353
